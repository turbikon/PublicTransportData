# %% [markdown]
# ## Planning proyect

# %% [markdown]
# Firstly, it is necessary to define the relevant information to measure...
# Secondly, it is important to notice that information need to be collected following the next abstraction levels: per vehicle, per user, per path bucle, per day, etc...

# %% [markdown]
# <br>
# The next data structures define the static information related to the vehicle... it means they contain information that hardly change.
#
# ~~~
# Vehicle = {
#     string vehicle_id,
#     Owner owner_vehicle,
#     Route route,
#     int capacity,
#     License license,
#     Monitoring_System monitoring_system
# }
#
# License = {
#     Owner owner_license,
#     string unique_id,
#     int economical_number,
# }
#
# Owner = {
#     string owner_id,
#     string name,
#     User_Account user_account
# }
#
# User_Account = {
#     string email,
#     string password,
#     string phone,
#     User_Access user_access
# }
#
# User_Access = {
#     boolean access_1 : (True or False)
#     boolean access_2 : (True or False)
#     ...
# }
#
# Route = {
#     string route_id,
#     string route_description,
#     tuple steps : ('Step_1', 'Step_2', 'Step_3', ...),
#     tuple stops : ('Stop_1', 'Stop_2', 'Stop_3', ...),
#     Start start,
#     End end
# }
#
# Step = {
#     int step_id,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Stop = {
#     int stop_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Start = {
#     int start_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# End = {
#     int end_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Coordinates = {
#     tuple coordinates : (latitude, longitude)
# }
#
# Monitoring_System = {
#     string monitoring_system_id,
#     Cam_System cam_system,
#     Gps gps,
#     Payment_System payment_system,
#     Accelerometer_System accelerometer_system,
#     Communication_System communication_system
# }
#
# Cam_System = {
#     string cam_system_id,
#     tuple cams : ('Cam_1', 'Cam_2', 'Cam_3', ...),
#     tuple status : ('True', 'False', 'True', ...)
# }
#
# Cam = {
#     string cam_id,
#     string brand,
#     string resolution,
#     string location : ('position_1' or 'position_2' or 'position_3' ...),
#     boolean status : (True or False)
# }
#
# Gps = {
#     string gps_id,
#     string brand,
#     boolean status
# }
#
# Payment_System = {
#     string payment_system_id,
#     tuple payment_systems : ('payment_cash', 'Payment_Card', 'Payment_Mobile', ...),
#     tuple status : ('True', 'True', 'False', ...)
# }
#
# Payment_Card = {
#     string payment_card_id,
#     string payment_card_brand,
#     boolean status
# }
#
# Payment_Mobile = {
#     string payment_mobile_id,
#     string payment_mobile_brand,
#     boolean status
# }
#
# Accelerometer_System = {
#     string accelerometer_system_id,
#     tuple accelerometer : ('Accelerometer_1', 'Accelerometer_2', ...)
#     tuple status : ('True', 'True', ...)
# }
#
# Accelerometer = {
#     string accelerometer_id,
#     string accelerometer_brand,
#     boolean status : (True or False)
# }
#
# # Communication System to be defined...
#
# ~~~

# %% [markdown]
# <br>
# Passenger's desired data structure. This is the dynamic information, which is collected along the daily work of the vehicle. Some variables must be contrast with the static data shown above.
#
# ~~~
# Vehicle = {
#     string vehicle_id,
#     string owner_id,
#     list Passenger passengers,
#     list Vehicle_Behavior vehicle_behavior,
#     Monitoring_System monitoring_system,
#     Alert_System alert_system,
#     Payment_System payment_system
# }
#
# Passenger = {
#     array capture,
#     Coordinate start_trip,
#     Coordinate end_trip,
#     date star_time_trip,
#     date end_time_trip,
#     float payment,
#
#     # Events
#     def get_in () :
#         pass
#
#     def get_out () :
#         pass
#
#     # Methods
#     def calculate_payment () :
#         pass
# }
#
# Vehicle_Behavior = {
#     Tuple Gps.coordinates,
#     float accelerometer,
#     array distribution_cam,
# }
#
# Alert_System = {
#     string alter_system_id,
#     date date_alerts,
#     tuple Alert alerts,
# }
#
# Alert = {
#     string alert_id,
#     string alert_description,
#     date alert_time,
#     boolean notified,
#
#     # Events
#     def system_fail () :
#         '''Notify something is not working correctly'''
#         pass
#
#     def out_of_route () :
#         '''Notify vehicle is out of the specified route'''
#         pass
#
#     def acceleration () :
#         '''Notify bad driver behavior or vibration unexpected or possible crash'''
#         pass
#
#     def overflow () :
#         '''Notify there are more passengers than capacity'''
#         pass
# }
#
# Monitoring_System = {
#     string monitoring_system_id,
#     Cam_System cam_system,
#     Gps gps,
#     * Payment_System payment_system,
#     Accelerometer_System accelerometer_system,
#     Communication_System communication_system
# }
#
# Cam_System = {
#     string cam_system_id,
#     tuple cams : ('Cam_1', 'Cam_2', 'Cam_3', ...),
#     tuple status : ('True', 'False', 'True', ...)
# }
#
# Cam_Get_In_Get_Out = {
#     string cam_id,
#     string location,
#     boolean status,
#
#     # Events
#     def movement_detected () :
#         '''Monitoring if object get in or get out'''
#         pass
#
#     # Methods
#     def continous_monitoring () :
#         '''Permanent monitoring'''
#         pass
#
#     def get_in_detected () :
#         '''Triggering related variables'''
#         pass
#
#     def get_out_detected () :
#         '''Triggering related variables'''
#         pass
#
#     def status_check () :
#         '''Check if cam is working correctly'''
#         pass
# }
#
# Cam_Face_Capture = {
#     string cam_id,
#     string location,
#     boolean status,
#
#     # Methods
#     def face_capture () :
#         '''Take multiple captures of the passenger'''
#         pass
#
#     def status_check () :
#         '''Check if cam is working correctly'''
#         pass
#
#     '''Does it make sense to use face detection to counting passengers? This would need a high processor capability of on-board-system, that could be expensive'''
# }
#
# Cam_Distribution = {
#     string cam_id,
#     string location,
#     boolean status,
#
#     # Methods
#     def distribution_capture () :
#         '''Take regular captures about the distribution of the passengers in the vehicle'''
#         pass
#
#     def status_check () :
#         '''Check if cam is working correctly'''
#         pass
#
#     # Events
#     def movement_detected () :
#         '''Monitoring changes of passenger distirbution'''
#         pass
#
#     '''In some cases, the get-in/get-out cam might be used as distribution cam'''
# }
#
# Gps = {
#     string gps_id,
#     boolean status,
#     tuple coordenates,
#     float velocity,
#     date time,
#
#     # Methods
#     def status_check () :
#         '''Check if cam is working correctly'''
#         pass
#
#     def continuous_monitoring () :
#         '''Continuous satellite calls to compare read coordenates against Route data'''
#         pass
#
#     # Events
#     def movement_detected () :
#         '''Allowing movement and stops detection, make it possible to compare read coordenates against Route data'''
#         pass
# }
#
# Accelerometer_System = {
#     string accelerometer_system_id,
#     tuple accelerometer : ('Accelerometer_1', 'Accelerometer_2', ...)
#     tuple status : ('True', 'True', ...)
# }
#
# Accelerometer = {
#     string accelerometer_id,
#     boolean status,
#
#     # Methods
#     def status_check () :
#         '''Check if cam is working correctly'''
#         pass
#
#     def continuous_monitoring () :
#         '''Continuous monitoring'''
#         pass
# }
#
# Communication_System = {
#     string communication_system_id,
#     list communication_systems : (),
#     list status : ()
#
#     '''Maybe the GPS might be included in this system'''
# }
#
# WLAN_Communication = {
#     '''TBD later. Security protocol needs to be considered'''
# }
#
# Mobile_Communication = {
#     '''TBD later. Security protocol needs to be considered'''
# }
#
# Payment_System = {
#     string payment_system_id,
#     tuple payment_systems : ('payment_cash', 'Payment_Card', 'Payment_Mobile', ...),
#     tuple status : ('True', 'True', 'False', ...)
#
#     '''There are different ways to define the trip cost. If the trip cost isn't variable, there is not problem, but if it is, the system becomes challenging since this force the system to recognize appropiately to each passenger and calculate how long trip was. Of course, if there is a card or mobile payment system, more information is available for the passenger identification, but it doesn't solve the problem of tracking each person'''
# }
#
# Payment_Cash = {
#     string payment_cash_id,
#     float payment,
#
#     # Method
#     calculate_payment () :
#         '''Calculate trip cost'''
#         pass
# }
#
# Payment_Card = {
#     string payment_card_id,
#     float payment,
#     boolean status
#
#     # Methods
#     def status_check () :
#         '''Check if payment method is working correctly'''
#         pass
#
#     calculate_payment () :
#         '''Calculate trip cost'''
#         pass
# }
#
# Payment_Mobile = {
#     string payment_mobile_id,
#     float payment,
#     boolean status
#
#     # Methods
#     def status_check () :
#         '''Check if payment method is working correctly'''
#         pass
#
#     calculate_payment () :
#         '''Calculate trip cost'''
#         pass
# }
#
# ###
#
# Route = {
#     string route_id,
#     string route_description,
#     tuple steps : ('Step_1', 'Step_2', 'Step_3', ...),
#     tuple stops : ('Stop_1', 'Stop_2', 'Stop_3', ...),
#     Start start,
#     End end
# }
#
# Step = {
#     int step_id,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Stop = {
#     int stop_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Start = {
#     int start_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# End = {
#     int end_id,
#     string description,
#     Coordinates coordinates,
#     float tolerance
# }
#
# Coordinates = {
#     tuple coordinates : (latitude, longitude)
# }
#
# ~~~
